# %% [markdown]
# <a href="https://colab.research.google.com/github/srikumar03/Flutter_Bluetooth_Printer/blob/main/BYTS_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
a = np.array([1,2,3,4,5])
type(a)
a[1]
a
# Out:
# array([1, 2, 3, 4, 5])

# %%
s=pd.Series([1,2,3])
type(s)
#s[2]
# Out:
# pandas.core.series.Series

# %%
s.drop(1)
# Out:
# 0    1
# 2    3
# dtype: int64

# %%
print(s.iloc[1])#for index
s.loc[1]#for series
# Out:
# 2
# 2

# %%
ss= pd.Series([10,20,30,40,50],index=['a','a','c','d','e'])
ss
# Out:
# a    10
# a    20
# c    30
# d    40
# e    50
# dtype: int64

# %%
print(ss.loc['a'])
print(ss.iloc[1])
# Out:
# a    10
# a    20
# dtype: int64
# 20

# %%
data=[['Aa',10,'5-3-2003'],['Bb',None,100],[None,9,None]]
data
# Out:
# [['Aa', 10, '5-3-2003'], ['Bb', None, 100], [None, 9, None]]

# %%
df=pd.DataFrame(data)
df
# Out:
#       0     1         2
# 0    Aa  10.0  5-3-2003
# 1    Bb   NaN       100
# 2  None   9.0      None

# %%
print(df[0:2])
print("=================")
print(df[[1,2]])
# Out:
#     0     1         2
# 0  Aa  10.0  5-3-2003
# 1  Bb   NaN       100
# ...
#       1         2
# 0  10.0  5-3-2003
# 1   NaN       100
# 2   9.0      None

# %%
df=pd.DataFrame(data,columns=["A",'B','C'])
print(df)
print("===========")
print(df['A'])
print("===========")
df.head(1)
# Out:
#       A     B         C
# 0    Aa  10.0  5-3-2003
# 1    Bb   NaN       100
# 2  None   9.0      None
# ...
# 0      Aa
# 1      Bb
# 2    None
# Name: A, dtype: object
# ...
#     A     B         C
# 0  Aa  10.0  5-3-2003

# %%
df.tail(-2)
# Out:
#       A    B     C
# 2  None  9.0  None

# %%
print(df['A'][0])
print(df.loc[2,'C'])
print(df.iloc[1,0])
print(df[0:1])
# Out:
# Aa
# None
# Bb
#     A     B         C
# 0  Aa  10.0  5-3-2003

# %%
p=pd.Series([50,1,-2,3])
s.plot()
# Out:
# <Axes: >

# %%
ss.hist(bins=2)
# Out:
# <Axes: >

# %%
print(type(p))
p=p.to_numpy()
print(type(p))
# Out:
# <class 'pandas.core.series.Series'>
# <class 'numpy.ndarray'>

# %%
df
# Out:
#       A     B         C
# 0    Aa  10.0  5-3-2003
# 1    Bb   NaN       100
# 2  None   9.0      None

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       2 non-null      object
#  1   B       2 non-null      float64
#  2   C       2 non-null      object
# dtypes: float64(1), object(2)
# memory usage: 200.0+ bytes

# %%
df1=([[1,2,3],['aa','Bb','ccb'],[None ,'aba',None],[None,None,7],['None' ,'abc',3]])
df1=pd.DataFrame(df1,columns=['A','B','C'])
print(df1.isnull().sum())

print(df1.dropna(inplace=True))
print(df1)
# Out:
# A    2
# B    1
# C    1
# dtype: int64
# None
#       A    B    C
# 0     1    2    3
# 1    aa   Bb  ccb
# 4  None  abc    3

# %%
df1['B'].str.contains('b')
# Out:
# 0     NaN
# 1    True
# 4    True
# Name: B, dtype: object

# %%
print(df1.shape,end="\n\n")
print(df1.size,end="\n\n")
print(df1.axes,end="\n\n")
print(df1.ndim,end="\n\n")
print(df1.dtypes,end="\n\n")
print(df1.index,end="\n\n")
print(df1.columns,end="\n\n")
print(df1.values,end="\n\n")
# Out:
# (3, 3)
#
# 9
#
# [Int64Index([0, 1, 4], dtype='int64'), Index(['A', 'B', 'C'], dtype='object')]
#
# 2
#
# A    object
# B    object
# C    object
# dtype: object
#
# Int64Index([0, 1, 4], dtype='int64')
#
# Index(['A', 'B', 'C'], dtype='object')
#
# [[1 2 3]
#  ['aa' 'Bb' 'ccb']
#  ['None' 'abc' 3]]

# %%
a
# Out:
# array([1, 2, 3, 4, 5])

# %%
a>=4
# Out:
# array([False, False, False,  True,  True])

# %%
print(a[a>4])
print(a[a%2==0])
# Out:
# [5]
# [2 4]

# %%
df2=pd.read_html("https://en.wikipedia.org/wiki/Lamborghini")
df2
# Out:
# [                                       0  \
#  0                                    NaN
#  1   Headquarters in Sant'Agata Bolognese
#  2                                   Type
#  3                               Industry
#  4                                Founded
#  5                                Founder
#  6                           Headquarters
#  7                    Number of locations
#  8                            Area served
#  9                             Key people
#  10                     Production output
#  11                               Revenue
#  12                      Operating income
#  13                            Net income
#  14                          Total equity
#  15                                 Owner
#  16                   Number of employees
#  17                                Parent
#  18                          Subsidiaries
#  19                               Website
#
#                                                    1
# ...

# %%
df3=pd.read_table("https://raw.githubusercontent.com/nunnarilabs/ml/master/pandas/chipotle.tsv")
df3
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
type(df3)
# Out:
# pandas.core.frame.DataFrame

# %%
df3.isnull().sum()
# Out:
# order_id                 0
# quantity                 0
# item_name                0
# choice_description    1246
# item_price               0
# dtype: int64

# %%
df3.item_price= df3.item_price.str.replace('$','',regex=True)
df3.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN      2.39
# 1                                       [Clementine]      3.39
# 2                                            [Apple]      3.39
# 3                                                NaN      2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...     16.98

# %%
# df3.item_price=df3.item_price.astype(int)
df3.item_price=df3.item_price.astype(float)
# df3

# %%
df3.item_price*100
# df3.head()
# Out:
# 0        239.0
# 1        339.0
# 2        339.0
# 3        239.0
# 4       1698.0
#          ...
# 4617    1175.0
# 4618    1175.0
# 4619    1125.0
# 4620     875.0
# 4621     875.0
# Name: item_price, Length: 4622, dtype: float64

# %%
df_drink=df3[df3.item_price < 1.1]
df_drink.item_price
# Out:
# 28      1.09
# 34      1.09
# 53      1.09
# 87      1.09
# 107     1.09
#         ...
# 3936    1.09
# 4001    1.09
# 4008    1.09
# 4051    1.09
# 4069    1.09
# Name: item_price, Length: 106, dtype: float64

# %%
print(df_drink.item_name.unique())
print(df_drink.item_name.nunique())
# Out:
# ['Canned Soda' 'Bottled Water']
# 2

# %%
df3.item_name.value_counts()
# Out:
# Chicken Bowl                             726
# Chicken Burrito                          553
# Chips and Guacamole                      479
# Steak Burrito                            368
# Canned Soft Drink                        301
# Steak Bowl                               211
# Chips                                    211
# Bottled Water                            162
# Chicken Soft Tacos                       115
# Chips and Fresh Tomato Salsa             110
# Chicken Salad Bowl                       110
# Canned Soda                              104
# Side of Chips                            101
# Veggie Burrito                            95
# Barbacoa Burrito                          91
# Veggie Bowl                               85
# Carnitas Bowl                             68
# Barbacoa Bowl                             66
# Carnitas Burrito                          59
# Steak Soft Tacos                          55
# 6 Pack Soft Drink                         54
# ...

# %%
print(df3[df3.item_name=='Steak Salad'],end="\n\n----------------------------\n\n")
print(df3[df3.item_name=='Steak Salad'].choice_description.value_counts(),end="\n\n----------------------------\n\n")
print(df3[df3.item_name=='Steak Salad'].choice_description.unique(),end="\n\n----------------------------\n\n")
print(df3[df3.item_name=='Steak Salad'].choice_description.nunique())
# Out:
#       order_id  quantity    item_name  \
# 664        276         1  Steak Salad
# 752        311         1  Steak Salad
# 893        369         1  Steak Salad
# 3502      1406         1  Steak Salad
#
#                                      choice_description  item_price
# 664   [Tomatillo-Red Chili Salsa (Hot), [Black Beans...        8.99
# 752   [Tomatillo-Red Chili Salsa (Hot), [Black Beans...        8.99
# 893   [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...        8.99
# 3502                        [[Lettuce, Fajita Veggies]]        8.69
#
# ----------------------------
#
# [Tomatillo-Red Chili Salsa (Hot), [Black Beans, Rice, Fajita Veggies, Cheese, Lettuce]]    2
# [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sour Cream, Lettuce]]                           1
# [[Lettuce, Fajita Veggies]]                                                                1
# Name: choice_description, dtype: int64
#
# ----------------------------
#
# ...

# %%
print(df3.dropna(inplace=True))
# Out:
# None

# %%
df3[df3.choice_description.str.contains("Black Beans")].item_name.value_counts()
# Out:
# Chicken Bowl             386
# Chicken Burrito          282
# Steak Burrito            148
# Steak Bowl               110
# Veggie Bowl               60
# Veggie Burrito            55
# Chicken Salad Bowl        49
# Carnitas Bowl             39
# Barbacoa Bowl             37
# Barbacoa Burrito          30
# Carnitas Burrito          28
# Chicken Soft Tacos        19
# Chicken Crispy Tacos      14
# Veggie Salad Bowl         13
# Steak Salad Bowl          13
# Steak Soft Tacos          10
# Carnitas Soft Tacos        7
# Chicken Salad              7
# Veggie Soft Tacos          6
# Barbacoa Soft Tacos        6
# Veggie Salad               5
# Barbacoa Salad Bowl        4
# Barbacoa Crispy Tacos      3
# Carnitas Crispy Tacos      3
# Carnitas Salad Bowl        3
# Steak Crispy Tacos         2
# Steak Salad                2
# Salad                      2
# Burrito                    1
# Carnitas Salad             1
# Name: item_name, dtype: int64

# %%
df3[(df3.item_price < 10 ) & (df3.item_name == 'Steak Salad')].sort_values(['item_price'])
# Out:
#       order_id  quantity    item_name  \
# 3502      1406         1  Steak Salad
# 664        276         1  Steak Salad
# 752        311         1  Steak Salad
# 893        369         1  Steak Salad
#
#                                      choice_description  item_price
# 3502                        [[Lettuce, Fajita Veggies]]        8.69
# 664   [Tomatillo-Red Chili Salsa (Hot), [Black Beans...        8.99
# 752   [Tomatillo-Red Chili Salsa (Hot), [Black Beans...        8.99
# 893   [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...        8.99

# %%
df4=pd.read_csv("https://raw.githubusercontent.com/nunnarilabs/ml/master/pandas/imdb_1000.csv")
df4.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
df4[(df4.star_rating > 9) & (df4.content_rating == 'R')].sort_values('duration')
# Out:
#    star_rating                     title content_rating  genre  duration  \
# 0          9.3  The Shawshank Redemption              R  Crime       142
# 1          9.2             The Godfather              R  Crime       175
# 2          9.1    The Godfather: Part II              R  Crime       200
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...

# %%
df4[df4.genre.str.contains("Sci-Fi")]
# Out:
#      star_rating                          title content_rating   genre  \
# 145          8.2                   Blade Runner              R  Sci-Fi
# 321          8.0                         Brazil              R  Sci-Fi
# 408          7.9                        Gravity          PG-13  Sci-Fi
# 484          7.8  The Day the Earth Stood Still       APPROVED  Sci-Fi
# 637          7.7           The Butterfly Effect              R  Sci-Fi
#
#      duration                                        actors_list
# 145       117  [u'Harrison Ford', u'Rutger Hauer', u'Sean You...
# 321       132  [u'Jonathan Pryce', u'Kim Greist', u'Robert De...
# 408        91  [u'Sandra Bullock', u'George Clooney', u'Ed Ha...
# 484        92  [u'Michael Rennie', u'Patricia Neal', u'Hugh M...
# 637       113  [u'Ashton Kutcher', u'Amy Smart', u'Melora Wal...

# %%
ufo=pd.read_csv("https://raw.githubusercontent.com/nunnarilabs/ml/master/pandas/ufo.csv")
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
ufo.dropna(subset=['City','Shape Reported'],how='any').shape
# Out:
# (15576, 5)

# %%
ufo.dropna(subset=['City','Shape Reported'],how='all').shape
# Out:
# (18237, 5)

# %%
ufo['Shape Reported'].value_counts()
# Out:
# LIGHT        2803
# DISK         2122
# TRIANGLE     1889
# OTHER        1402
# CIRCLE       1365
# SPHERE       1054
# FIREBALL     1039
# OVAL          845
# CIGAR         617
# FORMATION     434
# VARIOUS       333
# RECTANGLE     303
# CYLINDER      294
# CHEVRON       248
# DIAMOND       234
# EGG           197
# FLASH         188
# TEARDROP      119
# CONE           60
# CROSS          36
# DELTA           7
# ROUND           2
# CRESCENT        2
# DOME            1
# PYRAMID         1
# FLARE           1
# HEXAGON         1
# Name: Shape Reported, dtype: int64

# %%
ufo['Shape Reported'].isnull().sum()
# Out:
# 2644

# %%
drink=pd.read_csv("https://raw.githubusercontent.com/nunnarilabs/ml/master/pandas/drinks.csv")
drink.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 6 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   country                       193 non-null    object
#  1   beer_servings                 193 non-null    int64
#  2   spirit_servings               193 non-null    int64
#  3   wine_servings                 193 non-null    int64
#  4   total_litres_of_pure_alcohol  193 non-null    float64
#  5   continent                     193 non-null    object
# dtypes: float64(1), int64(3), object(2)
# memory usage: 9.2+ KB

# %%
drink.beer_servings.describe()
# Out:
# count    193.000000
# mean     106.160622
# std      101.143103
# min        0.000000
# 25%       20.000000
# 50%       76.000000
# 75%      188.000000
# max      376.000000
# Name: beer_servings, dtype: float64

# %%
drink[drink.continent == 'Asia']
# Out:
#                   country  beer_servings  spirit_servings  wine_servings  \
# 0             Afghanistan              0                0              0
# 12                Bahrain             42               63              7
# 13             Bangladesh              0                0              0
# 19                 Bhutan             23                0              0
# 24                 Brunei             31                2              1
# 30               Cambodia             57               65              1
# 36                  China             79              192              8
# 46            North Korea              0                0              0
# 77                  India              9              114              0
# 78              Indonesia              5                1              0
# 79                   Iran              0                0              0
# 80                   Iraq              9                3              0
# ...

# %%
drink[drink.continent == 'Asia'].beer_servings.agg(['mean','min','max','median','std'])
# Out:
# mean       37.045455
# min         0.000000
# max       247.000000
# median     17.500000
# std        49.469725
# Name: beer_servings, dtype: float64

# %%
drink.groupby('continent').beer_servings.agg('mean','min','max')
# Out:
# continent
# Africa            61.471698
# Asia              37.045455
# Europe           193.777778
# North America    145.434783
# Oceania           89.687500
# South America    175.083333
# Name: beer_servings, dtype: float64
